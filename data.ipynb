# %%
import pandas as pd
df = pd.read_csv('data/log/0.csv')
print(df.shape)
# Out:
# (23999040, 18)

# %%
df[df['advertiserNumber'] == 1.0]
# Out:
#           deliveryPeriodIndex  advertiserNumber  advertiserCategoryIndex  \
# 1                         0.0               1.0                      0.0
# 49                        0.0               1.0                      0.0
# 97                        0.0               1.0                      0.0
# 145                       0.0               1.0                      0.0
# 193                       0.0               1.0                      0.0
# ...                       ...               ...                      ...
# 23998801                  0.0               1.0                      0.0
# 23998849                  0.0               1.0                      0.0
# 23998897                  0.0               1.0                      0.0
# 23998945                  0.0               1.0                      0.0
# 23998993                  0.0               1.0                      0.0
#
#           budget  CPAConstraint  timeStepIndex  remainingBudget  pvIndex  \
# ...
